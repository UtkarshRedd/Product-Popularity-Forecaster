# %%
import pandas as pd
import os
from pathlib import Path

# %%
pd.__version__
# Out:
# '2.0.1'

# %%
ROOT_DIR = Path(os.getcwd()).parent.parent.parent
ROOT_DIR = str(ROOT_DIR)
ROOT_DIR = ROOT_DIR.replace('\\', "/")
RAW_DATA_FILE_NAME = 'cleaned_data_2020-10-01_2021-10-18.parquet'
data = pd.read_parquet(f"{ROOT_DIR}/datasets/{RAW_DATA_FILE_NAME}")
data
# Out:
#            FC City  SAP Article Id                  SAP Article Description
# 0            ADONI       490000002  DAAWAT ROZANA GOLD BASMATI RICE 1 kg PP  \
# 1            ADONI       490000002  DAAWAT ROZANA GOLD BASMATI RICE 1 kg PP
# 2            ADONI       490000002  DAAWAT ROZANA GOLD BASMATI RICE 1 kg PP
# 3            ADONI       490000002  DAAWAT ROZANA GOLD BASMATI RICE 1 kg PP
# 4            ADONI       490000002  DAAWAT ROZANA GOLD BASMATI RICE 1 kg PP
# ...            ...             ...                                      ...
# 16546744  VADODARA       491336857            BALAJI FARALI CHEVDO 400 g PP
# 16546745  VADODARA       491336857            BALAJI FARALI CHEVDO 400 g PP
# 16546746  VADODARA       491336857            BALAJI FARALI CHEVDO 400 g PP
# 16546747  VADODARA       491336857            BALAJI FARALI CHEVDO 400 g PP
# 16546748  VADODARA       491336857            BALAJI FARALI CHEVDO 400 g PP
#
#                 Category                         L1                    L2
# 0         Staples (Rest)  Foodgrains, Oils & Masala  Rice & Rice Products  \
# 1         Staples (Rest)  Foodgrains, Oils & Masala  Rice & Rice Products
# 2         Staples (Rest)  Foodgrains, Oils & Masala  Rice & Rice Products
# 3         Staples (Rest)  Foodgrains, Oils & Masala  Rice & Rice Products
# 4         Staples (Rest)  Foodgrains, Oils & Masala  Rice & Rice Products
# ...                  ...                        ...                   ...
# 16546744       FMCG Food     Snacks & Confectionery      Snacks & Namkeen
# 16546745       FMCG Food     Snacks & Confectionery      Snacks & Namkeen
# 16546746       FMCG Food     Snacks & Confectionery      Snacks & Namkeen
# 16546747       FMCG Food     Snacks & Confectionery      Snacks & Namkeen
# 16546748       FMCG Food     Snacks & Confectionery      Snacks & Namkeen
#
#                     L3       Date  Net_Sales  Net_Quantity  Net_Merchants
# 0         Basmati Rice 2020-10-01        0.0           0.0            0.0
# 1         Basmati Rice 2020-10-02        0.0           0.0            0.0
# 2         Basmati Rice 2020-10-03        0.0           0.0            0.0
# 3         Basmati Rice 2020-10-04        0.0           0.0            0.0
# 4         Basmati Rice 2020-10-05        0.0           0.0            0.0
# ...                ...        ...        ...           ...            ...
# 16546744       Namkeen 2021-10-14        0.0           0.0            0.0
# 16546745       Namkeen 2021-10-15        0.0           0.0            0.0
# 16546746       Namkeen 2021-10-16        0.0           0.0            0.0
# 16546747       Namkeen 2021-10-17        0.0           0.0            0.0
# 16546748       Namkeen 2021-10-18        0.0           0.0            0.0
#
# [16546749 rows x 11 columns]
